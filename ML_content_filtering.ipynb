# %%
import pandas as pd
import configparser
import pymysql
from sqlalchemy import create_engine
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from math import sqrt
from sklearn.decomposition import PCA
import warnings; warnings.simplefilter('ignore')

# %%
parser = configparser.ConfigParser()
parser.read("config\mysql.conf")
hostname = parser.get("mysql_config", "hostname")
username = parser.get("mysql_config", "username")
password = parser.get("mysql_config", "password")
dbname = parser.get("mysql_config", "database")
port = parser.get("mysql_config", "port")

conn_str = 'mysql+pymysql://' + username + ':' + password + '@' + hostname + '/' + dbname
db_connection = create_engine(conn_str)

# %%
mm = pd.read_sql('SELECT * FROM movies_dwh.v_ml_movies_metadata', con = db_connection)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 ratings = pd.read_sql('SELECT * FROM movies_dwh.v_ml_movies_metadata', con = db_connection)
#
# File ~\anaconda3.1\envs\movies\lib\site-packages\pandas\io\sql.py:663, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     653     return pandas_sql.read_table(
#     654         sql,
#     655         index_col=index_col,
#    (...)
#     660         dtype_backend=dtype_backend,
#     661     )
#     662 else:
# --> 663     return pandas_sql.read_query(
#     664         sql,
#     665         index_col=index_col,
#     666         params=params,
#     667         coerce_float=coerce_float,
#     668         parse_dates=parse_dates,
#     669         chunksize=chunksize,
#     670         dtype_backend=dtype_backend,
#     671         dtype=dtype,
#     672     )
#
# File ~\anaconda3.1\envs\movies\lib\site-packages\pandas\io\sql.py:1738, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    1681 def read_query(
#    1682     self,
#    1683     sql: str,
#    (...)
#    1690     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    1691 ) -> DataFrame | Iterator[DataFrame]:
#    1692     """
#    1693     Read SQL query into a DataFrame.
#    1694
#    (...)
#    1736
#    1737     """
# -> 1738     result = self.execute(sql, params)
#    1739     columns = result.keys()
#    1741     if chunksize is not None:
#
# File ~\anaconda3.1\envs\movies\lib\site-packages\pandas\io\sql.py:1562, in SQLDatabase.execute(self, sql, params)
#    1560 args = [] if params is None else [params]
#    1561 if isinstance(sql, str):
# -> 1562     return self.con.exec_driver_sql(sql, *args)
#    1563 return self.con.execute(sql, *args)
#
# File ~\anaconda3.1\envs\movies\lib\site-packages\sqlalchemy\engine\base.py:1779, in Connection.exec_driver_sql(self, statement, parameters, execution_options)
#    1774 execution_options = self._execution_options.merge_with(
#    1775     execution_options
#    1776 )
#    1778 dialect = self.dialect
# -> 1779 ret = self._execute_context(
#    1780     dialect,
#    1781     dialect.execution_ctx_cls._init_statement,
#    1782     statement,
#    1783     None,
#    1784     execution_options,
#    1785     statement,
#    1786     distilled_parameters,
#    1787 )
#    1789 return ret
#
# File ~\anaconda3.1\envs\movies\lib\site-packages\sqlalchemy\engine\base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844     return self._exec_insertmany_context(dialect, context)
#    1845 else:
# -> 1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File ~\anaconda3.1\envs\movies\lib\site-packages\sqlalchemy\engine\base.py:1986, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1983     result = context._setup_result_proxy()
#    1985 except BaseException as e:
# -> 1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#    1990 return result
#
# File ~\anaconda3.1\envs\movies\lib\site-packages\sqlalchemy\engine\base.py:2356, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2354     else:
#    2355         assert exc_info[1] is not None
# -> 2356         raise exc_info[1].with_traceback(exc_info[2])
#    2357 finally:
#    2358     del self._reentrant_error
#
# File ~\anaconda3.1\envs\movies\lib\site-packages\sqlalchemy\engine\base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1965                 break
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#    1972     self.dispatch.after_cursor_execute(
#    1973         self,
#    1974         cursor,
#    (...)
#    1978         context.executemany,
#    1979     )
#
# File ~\anaconda3.1\envs\movies\lib\site-packages\sqlalchemy\engine\default.py:924, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     923 def do_execute(self, cursor, statement, parameters, context=None):
# --> 924     cursor.execute(statement, parameters)
#
# File ~\anaconda3.1\envs\movies\lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File ~\anaconda3.1\envs\movies\lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File ~\anaconda3.1\envs\movies\lib\site-packages\pymysql\connections.py:558, in Connection.query(self, sql, unbuffered)
#     556     sql = sql.encode(self.encoding, "surrogateescape")
#     557 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 558 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     559 return self._affected_rows
#
# File ~\anaconda3.1\envs\movies\lib\site-packages\pymysql\connections.py:822, in Connection._read_query_result(self, unbuffered)
#     820 else:
#     821     result = MySQLResult(self)
# --> 822     result.read()
#     823 self._result = result
#     824 if result.server_status is not None:
#
# File ~\anaconda3.1\envs\movies\lib\site-packages\pymysql\connections.py:1207, in MySQLResult.read(self)
#    1205         self._read_load_local_packet(first_packet)
#    1206     else:
# -> 1207         self._read_result_packet(first_packet)
#    1208 finally:
#    1209     self.connection = None
#
# File ~\anaconda3.1\envs\movies\lib\site-packages\pymysql\connections.py:1284, in MySQLResult._read_result_packet(self, first_packet)
#    1282 self.field_count = first_packet.read_length_encoded_integer()
#    1283 self._get_descriptions()
# -> 1284 self._read_rowdata_packet()
#
# File ~\anaconda3.1\envs\movies\lib\site-packages\pymysql\connections.py:1331, in MySQLResult._read_rowdata_packet(self)
#    1329 rows = []
#    1330 while True:
# -> 1331     packet = self.connection._read_packet()
#    1332     if self._check_packet_is_eof(packet):
#    1333         self.connection = None  # release reference to kill cyclic reference.
#
# File ~\anaconda3.1\envs\movies\lib\site-packages\pymysql\connections.py:758, in Connection._read_packet(self, packet_type)
#     752     raise err.InternalError(
#     753         "Packet sequence number wrong - got %d expected %d"
#     754         % (packet_number, self._next_seq_id)
#     755     )
#     756 self._next_seq_id = (self._next_seq_id + 1) % 256
# --> 758 recv_data = self._read_bytes(bytes_to_read)
#     759 if DEBUG:
#     760     dump_packet(recv_data)
#
# File ~\anaconda3.1\envs\movies\lib\site-packages\pymysql\connections.py:779, in Connection._read_bytes(self, num_bytes)
#     777 while True:
#     778     try:
# --> 779         data = self._rfile.read(num_bytes)
#     780         break
#     781     except OSError as e:
#
# File ~\anaconda3.1\envs\movies\lib\socket.py:669, in SocketIO.readinto(self, b)
#     667 while True:
#     668     try:
# --> 669         return self._sock.recv_into(b)
#     670     except timeout:
#     671         self._timeout_occurred = True
#
# KeyboardInterrupt:
